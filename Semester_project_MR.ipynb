# %% [markdown]
# # Mobile Robotics Semester Project Notebook
#
# **Course:** Mobile Robotics
# **Submitted to:** Dr. Talha Manzoor, Dr. AbuBakr Muhammad
# **Submitted by:** Zainab Ishtiaq
# **Roll #:** 24260003 MS Digital and Embedded Systems
# **Email:** 24260003
# **Date:** 23rd December 2025
#
# ---
#
# ### Reference Paper
# - **Paper title:** Camera-based mapping in search-and-rescue via flying andground robot teams
# - **Paper link:** https://doi.org/10.1007/s00138-024-01594-4
# - **Video link:** https://youtu.be/Zv_d28XeWFc?si=4-9ERZR77axTCBW7
# ---
#
# ### Brief Summary of the Paper
#
# The referenced paper proposes a camera-based victim detection, mapping, and tracking framework for Search and Rescue (SAR) using a team of aerial and ground robots. The paper exploit both aerial and ground robots (Fig 1) to provide distance and movement measures. Human victims are detected using pose-based DL model (YOLO8N), and missing or occluded body landmarks are reconstructed as well. Detected victim positions from multiple platforms are projected into a common ground plane and fused over time using a Kalman Filter (KF) to obtain smooth and robust 2D trajectories, even in the presence of noise and missed detection.
#
# ![Figure 1: Aerial–Ground SAR System](figs/fig_1.png)
#
#
# In our project we have simulated the framework in real world using ultralytics models( yolo8n,10n) and focused on 2D tracking of the victim who is moving randomly. The video used is shot from the 2nd floor of the ground(aerial_view) and filtering is done for varying frame strides to showcase nature of a constant velocity KF filter. The sections are as follows:
# ####    1- Victim Detection
# ####    2- Victim Localization(2d)
# ####    3- Victim Tracking

# %% [markdown]
# # 1- Victim Detection
# The paper models victim detection through **human pose estimation**, using a fixed set of **17 anatomical landmarks** (COCO keypoint format). These landmarks jointly define the posture, orientation, and spatial extent of a human body and are robust to partial occlusions compared to simple bounding boxes.
#
# ##### The 17 Body Landmarks
#
#
# ![Figure 2: 17 LM](figs/fig_2.png)
#
# Reference: https://docs.ultralytics.com/tasks/pose/
#
# These landmarks allow the system to reason about body orientation, limb symmetry, and approximate body dimensions, which are critical in SAR scenarios where victims may be partially visible.
#
# ### 1. Pose detection
# Ultralytics YOLO requires setup of pytorch and some dependencies. Once model is downloaded our videos for Ground and Aerial views used as inputs.
#
# Relevant output includes: boundingbox info, coorindates of victim, 17 landmarks, confidence

# %%
from ultralytics import YOLO
model = YOLO("yolov8n-pose.pt")

# process each video (ground and aerial)
results_ground = model("vid1_A_ground.mov", imgsz=640, conf=0.2)
results_aerial = model("Data/vid1_A_aerial.mp4", imgsz=640, conf=0.2)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 21.7ms
# video 1/1 (frame 2/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 17.2ms
# video 1/1 (frame 3/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 14.6ms
# video 1/1 (frame 4/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 20.2ms
# video 1/1 (frame 5/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 12.7ms
# video 1/1 (frame 6/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 18.0ms
# video 1/1 (frame 7/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 18.2ms
# video 1/1 (frame 8/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 19.1ms
# video 1/1 (frame 9/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 19.4ms
# video 1/1 (frame 10/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 14.9ms
# video 1/1 (frame 11/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 14.6ms
# video 1/1 (frame 12/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 20.2ms
# video 1/1 (frame 13/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 16.6ms
# video 1/1 (frame 14/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 13.9ms
# video 1/1 (frame 15/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 15.6ms
# video 1/1 (frame 16/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 15.5ms
# video 1/1 (frame 17/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 14.9ms
# video 1/1 (frame 18/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person,
494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 18.9ms
# video 1/1 (frame 480/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 21.8ms
# video 1/1 (frame 481/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 11.6ms
# video 1/1 (frame 482/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 12.2ms
# video 1/1 (frame 483/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 14.2ms
# video 1/1 (frame 484/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 10.9ms
# video 1/1 (frame 485/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 15.9ms
# video 1/1 (frame 486/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 14.4ms
# video 1/1 (frame 487/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 14.3ms
# video 1/1 (frame 488/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 15.0ms
# video 1/1 (frame 489/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 17.7ms
# video 1/1 (frame 490/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 12.6ms
# video 1/1 (frame 491/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 13.2ms
# video 1/1 (frame 492/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 15.3ms
# video 1/1 (frame 493/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 20.1ms
# video 1/1 (frame 494/494) c:\Users\LENOVO\Desktop\LUMS\mobile robotics\project\Semester_project_MR_24260003\Data\vid1_A_aerial.mp4: 384x640 1 person, 15.2ms
# Speed: 2.9ms preprocess, 15.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ### 2. Visualize
# Let's print the video with annotated 17 landmarks using cv2

# %%
import cv2

cap = cv2.VideoCapture("Data/vid1_A_aerial.mp4")

for frame_idx, r in enumerate(results_aerial):
    ret, frame = cap.read()
    if not ret:
        break

    if frame_idx % 10 != 0:
        continue

    clean = frame.copy()

    if r.keypoints is not None and len(r.keypoints.xy) > 0:
        kps = r.keypoints.xy[0]
        for (x, y) in kps:
            cv2.circle(clean, (int(x), int(y)), 2, (0,255,0), -1)

    small = cv2.resize(clean, (0,0), fx=1.5, fy=1.5)
    cv2.imshow("Aerial Video", small)

    if cv2.waitKey(100) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ![Figure 3: Detected pose](figs/fig_3.png)

# %% [markdown]
# ### 3- Victim localization
# The paper estimates occluded position of victims based off symmetry and analytical measures.
#
# ![Figure 4: Occlusions](figs/fig_4.png)
#
# Instead of using the full body model as emphasized in the paper, I approximate the victim position using the **centroid of the detected keypoints**.
#
# The centroid is computed as the mean of all valid (x, y) landmark coordinates:
# - It is robust to missing limbs.
# - It simplifies downstream processing.
# - It provides a stable 2D position suitable for Kalman filtering.
#
# This is a deliberate simplification that preserves the tracking objective while reducing geometric complexity.

# %%
def get_victim_xy(result, person_id=0, conf_thresh=0.3):
    """
    Compute victim (X, Y) position in image pixel coordinates
    using a confidence-weighted centroid of YOLOv8 pose keypoints.

    Returns
    -------
    (x, y) : tuple or None
        Victim position in pixel coordinates, or None if not enough data
    """

    # No pose detected or empty keypoints
    if result.keypoints is None or len(result.keypoints.data) == 0:
        return None
    
    # Check if person_id exists in the detected persons
    if person_id >= len(result.keypoints.data):
        return None

    # Extract keypoints for selected person
    # Shape: (17, 3) → [x, y, confidence]
    kps = result.keypoints.data[person_id]

    xy = kps[:, :2]      # (17, 2) pixel locations
    conf = kps[:, 2]     # (17,) confidence values

    # Keep only reliable keypoints
    valid = conf > conf_thresh
    if valid.sum() < 3:  # too few points → unstable centroid
        return None

    xy = xy[valid]
    conf = conf[valid]

    # Confidence-weighted centroid
    x = (xy[:, 0] * conf).sum() / conf.sum()
    y = (xy[:, 1] * conf).sum() / conf.sum()

    return float(x), float(y)

# %%
for r in results_aerial:
    victim_xy = get_victim_xy(r)
    
    if victim_xy is not None:
        x, y = victim_xy
        # Feed (x, y) into Kalman Filter
        print(f"Victim position: x={x:.1f}, y={y:.1f}")
    else:

        print("No victim detected in this frame")
        continue
# Out:
# Victim position: x=809.5, y=193.4
# Victim position: x=808.7, y=194.7
# Victim position: x=808.3, y=195.1
# Victim position: x=807.7, y=196.4
# Victim position: x=807.5, y=196.7
# Victim position: x=807.5, y=197.1
# Victim position: x=807.2, y=197.5
# Victim position: x=807.1, y=197.8
# Victim position: x=808.1, y=197.6
# Victim position: x=806.2, y=199.4
# Victim position: x=806.6, y=199.7
# Victim position: x=806.1, y=200.4
# Victim position: x=806.3, y=200.0
# Victim position: x=806.2, y=200.1
# Victim position: x=806.7, y=199.7
# Victim position: x=807.8, y=200.2
# Victim position: x=807.4, y=200.4
# Victim position: x=807.1, y=201.0
# Victim position: x=806.2, y=201.6
# Victim position: x=807.3, y=200.8
# Victim position: x=806.7, y=202.4
# Victim position: x=807.1, y=202.9
# Victim position: x=807.4, y=203.4
# Victim position: x=807.5, y=203.8
# Victim position: x=806.7, y=205.3
# Victim position: x=808.4, y=203.6
# Victim position: x=808.0, y=204.5
# Victim position: x=807.2, y=205.3
# Victim position: x=806.0, y=206.5
# Victim position: x=807.4, y=204.6
# Victim position: x=807.7, y=204.0
# Victim position: x=807.6, y=203.8
# Victim position: x=807.6, y=204.1
# Victim position: x=807.2, y=204.9
# Victim position: x=807.1, y=205.4
# Victim position: x=806.8, y=205.9
# Victim position: x=806.3, y=206.3
# Victim position: x=804.2, y=207.9
# Victim position: x=803.7, y=209.5
# Victim position: x=804.1, y=209.8
# Victim position: x=803.9, y=210.9
# Victim position: x=804.9, y=208.8
# Victim position: x=804.8, y=209.3
# Victim position: x=805.6, y=209.3
# Victim position: x=805.7, y=208.9
# Victim position: x=804.7, y=207.9
# Victim position: x=805.0, y=207.8
# Victim position: x=805.0, y=205.4
# Victim position: x=801.5, y=209.1
# Victim position: x=799.8, y=209.4
# Victim position: x=798.5, y=209.9
# Victim position: x=796.1, y=211.0
# Victim position: x=793.7, y=210.5
# Victim position: x=793.3, y=208.8
# Victim position: x=791.2, y=208.7
# Victim position: x=789.2, y=207.4
# Victim position: x=786.3, y=208.0
# Victim position: x=785.9, y=207.0
# Victim position: x=781.9, y=207.4
# Victim position: x=780.5, y=205.5
# Victim position: x=777.4, y=206.9
# Victim position: x=775.2, y=207.6
# Victim position: x=773.2, y=206.3
# Victim position: x=770.2, y=205.6
# Victim position: x=768.9, y=200.6
# Victim position: x=766.3, y=198.7
# Victim position: x=765.5, y=197.6
# Victim position: x=762.6, y=198.3
# Victim position: x=760.5, y=197.1
# Victim position: x=757.4, y=196.3
# Victim position: x=756.7, y=194.5
# Victim position: x=753.1, y=194.4
# Victim position: x=752.3, y=193.8
# Victim position: x=747.7, y=197.2
# Victim position: x=744.9, y=197.4
# Victim position: x=741.9, y=198.5
# Victim position: x=740.9, y=198.1
# Victim position: x=738.4, y=197.1
# Victim position: x=735.2, y=196.1
# Victim position: x=730.4, y=196.4
# Victim position: x=728.7, y=193.2
# Victim position: x=725.1, y=195.0
# Victim position: x=721.6, y=196.4
# Victim position: x=719.8, y=193.4
# Victim position: x=717.2, y=193.8
# Victim position: x=715.2, y=193.7
# Victim position: x=710.8, y=195.1
# Victim position: x=709.0, y=193.1
# Victim position: x=708.2, y=192.7
# Victim position: x=705.5, y=192.6
# Victim position: x=702.6, y=192.4
# Victim position: x=699.6, y=191.7
# Victim position: x=696.2, y=189.3
# Victim position: x=691.6, y=190.9
# Victim position: x=688.9, y=188.7
# Victim position: x=684.1, y=189.3
# Victim position: x=681.5, y=188.4
# Victim position: x=682.1, y=184.4
# Victim position: x=679.8, y=183.3
# Victim position: x=677.3, y=182.3
# Victim position: x=673.8, y=183.1
# Victim position: x=672.3, y=180.5
# Victim position: x=669.7, y=178.8
# Victim position: x=665.5, y=180.6
# Victim position: x=662.4, y=181.5
# Victim position: x=659.6, y=183.1
# Victim position: x=655.8, y=182.2
# Victim position: x=653.0, y=181.9
# Victim position: x=649.3, y=181.4
# Victim position: x=647.5, y=180.0
# Victim position: x=643.5, y=180.8
# Victim position: x=640.4, y=180.3
# Victim position: x=637.4, y=180.2
# Victim position: x=635.3, y=179.1
# Victim position: x=632.9, y=177.9
# Victim position: x=629.2, y=178.0
# Victim position: x=627.6, y=176.4
# Victim position: x=623.8, y=176.7
# Victim position: x=621.7, y=174.9
# Victim position: x=619.3, y=175.0
# Victim position: x=614.8, y=174.6
# Victim position: x=612.8, y=176.6
# Victim position: x=609.2, y=173.0
# Victim position: x=605.8, y=170.6
# Victim position: x=602.0, y=172.3
# Victim position: x=598.0, y=173.2
# Victim position: x=594.6, y=168.5
# Victim position: x=592.7, y=166.4
# Victim position: x=590.1, y=166.3
# Victim position: x=589.6, y=164.3
# Victim position: x=586.2, y=164.5
# Victim position: x=583.7, y=165.6
# Victim position: x=579.2, y=166.3
# Victim position: x=577.4, y=164.5
# Victim position: x=573.3, y=167.0
# Victim position: x=571.6, y=167.3
# Victim position: x=568.4, y=167.7
# Victim position: x=565.3, y=167.0
# Victim position: x=562.6, y=167.9
# Victim position: x=559.7, y=168.8
# Victim position: x=555.1, y=168.1
# Victim position: x=553.9, y=166.3
# Victim position: x=552.1, y=165.8
# Victim position: x=549.3, y=164.1
# Victim position: x=547.1, y=161.8
# Victim position: x=544.6, y=162.4
# Victim position: x=542.7, y=162.0
# Victim position: x=540.0, y=164.7
# Victim position: x=537.4, y=164.5
# Victim position: x=534.7, y=162.9
# Victim position: x=531.7, y=164.1
# Victim position: x=527.9, y=164.2
# Victim position: x=525.4, y=162.7
# Victim position: x=523.0, y=161.5
# Victim position: x=519.6, y=162.8
# Victim position: x=515.7, y=160.6
# Victim position: x=513.5, y=161.2
# Victim position: x=509.8, y=161.1
# Victim position: x=508.3, y=160.3
# No victim detected in this frame
# No victim detected in this frame
# Victim position: x=500.7, y=160.4
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# Victim position: x=487.1, y=164.1
# No victim detected in this frame
# Victim position: x=481.4, y=166.8
# Victim position: x=478.3, y=164.7
# Victim position: x=475.5, y=165.1
# No victim detected in this frame
# No victim detected in this frame
# Victim position: x=467.1, y=166.9
# No victim detected in this frame
# Victim position: x=463.1, y=163.9
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# Victim position: x=453.6, y=164.6
# Victim position: x=450.5, y=166.0
# Victim position: x=448.1, y=165.1
# Victim position: x=444.0, y=166.1
# Victim position: x=440.5, y=167.0
# Victim position: x=437.4, y=168.4
# Victim position: x=434.7, y=169.3
# Victim position: x=430.9, y=167.0
# Victim position: x=428.4, y=163.7
# Victim position: x=425.3, y=164.7
# Victim position: x=423.7, y=162.3
# Victim position: x=420.8, y=161.3
# Victim position: x=418.8, y=159.6
# No victim detected in this frame
# Victim position: x=413.4, y=160.6
# No victim detected in this frame
# No victim detected in this frame
# Victim position: x=406.1, y=167.4
# Victim position: x=404.2, y=165.3
# Victim position: x=399.8, y=165.0
# Victim position: x=397.1, y=166.0
# Victim position: x=394.1, y=166.7
# Victim position: x=390.5, y=165.1
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# Victim position: x=362.2, y=169.3
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# Victim position: x=327.4, y=179.9
# Victim position: x=325.7, y=180.1
# No victim detected in this frame
# Victim position: x=322.8, y=181.5
# Victim position: x=320.7, y=183.2
# Victim position: x=319.4, y=184.1
# Victim position: x=318.2, y=184.4
# Victim position: x=315.8, y=184.9
# Victim position: x=313.4, y=185.9
# Victim position: x=311.5, y=188.7
# Victim position: x=309.4, y=182.6
# Victim position: x=308.3, y=186.2
# Victim position: x=307.0, y=187.7
# Victim position: x=305.4, y=189.2
# Victim position: x=303.9, y=193.1
# Victim position: x=302.3, y=193.7
# Victim position: x=300.7, y=195.3
# Victim position: x=299.0, y=197.3
# Victim position: x=296.8, y=199.9
# Victim position: x=294.5, y=201.5
# Victim position: x=292.4, y=201.8
# Victim position: x=292.0, y=201.6
# Victim position: x=290.2, y=203.0
# Victim position: x=288.3, y=203.3
# Victim position: x=287.9, y=204.9
# Victim position: x=286.9, y=204.3
# Victim position: x=285.6, y=206.5
# Victim position: x=285.0, y=208.2
# Victim position: x=284.3, y=209.3
# Victim position: x=283.7, y=210.9
# Victim position: x=283.1, y=212.3
# Victim position: x=282.7, y=214.9
# Victim position: x=282.7, y=217.3
# Victim position: x=282.7, y=218.6
# Victim position: x=282.4, y=221.2
# Victim position: x=282.4, y=223.0
# Victim position: x=282.8, y=224.7
# Victim position: x=282.9, y=226.4
# Victim position: x=282.5, y=227.9
# Victim position: x=282.9, y=229.2
# Victim position: x=282.9, y=230.0
# Victim position: x=282.7, y=230.0
# Victim position: x=282.9, y=231.5
# Victim position: x=282.8, y=233.5
# Victim position: x=283.1, y=236.0
# Victim position: x=283.1, y=236.8
# Victim position: x=283.9, y=238.4
# Victim position: x=284.6, y=241.5
# Victim position: x=286.3, y=242.1
# Victim position: x=287.4, y=244.4
# Victim position: x=287.8, y=246.3
# Victim position: x=289.1, y=247.9
# Victim position: x=289.3, y=252.2
# Victim position: x=291.8, y=251.5
# Victim position: x=292.1, y=256.0
# Victim position: x=293.6, y=260.2
# Victim position: x=294.6, y=262.8
# Victim position: x=294.4, y=264.2
# Victim position: x=296.0, y=265.8
# Victim position: x=298.1, y=262.6
# Victim position: x=298.4, y=263.3
# Victim position: x=302.8, y=263.9
# Victim position: x=303.5, y=268.6
# Victim position: x=306.4, y=266.5
# Victim position: x=308.2, y=270.0
# Victim position: x=308.6, y=273.7
# Victim position: x=312.6, y=271.8
# Victim position: x=313.9, y=267.6
# Victim position: x=315.1, y=266.1
# No victim detected in this frame
# No victim detected in this frame
# Victim position: x=323.4, y=264.7
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# Victim position: x=386.4, y=270.4
# No victim detected in this frame
# No victim detected in this frame
# No victim detected in this frame
# Victim position: x=393.6, y=268.3
# Victim position: x=398.8, y=273.5
# Victim position: x=401.7, y=272.5
# Victim position: x=404.7, y=272.0
# Victim position: x=406.4, y=273.0
# No victim detected in this frame
# No victim detected in this frame
# Victim position: x=414.2, y=267.0
# Victim position: x=413.9, y=269.3
# Victim position: x=417.1, y=267.5
# Victim position: x=420.3, y=269.1
# Victim position: x=423.0, y=263.5
# Victim position: x=425.7, y=268.2
# No victim detected in this frame
# No victim detected in this frame
# Victim position: x=431.7, y=271.4
# Victim position: x=434.4, y=271.7
# Victim position: x=437.5, y=271.0
# Victim position: x=437.4, y=273.6
# Victim position: x=441.4, y=266.4
# Victim position: x=443.2, y=267.2
# Victim position: x=442.3, y=273.7
# Victim position: x=442.7, y=269.4
# Victim position: x=445.7, y=270.3
# Victim position: x=450.0, y=263.3
# Victim position: x=452.6, y=265.3
# Victim position: x=454.3, y=265.9
# Victim position: x=458.5, y=266.2
# Victim position: x=462.0, y=264.6
# Victim position: x=464.4, y=266.9
# Victim position: x=468.2, y=266.4
# Victim position: x=470.5, y=264.1
# Victim position: x=473.3, y=266.0
# Victim position: x=476.1, y=269.4
# Victim position: x=477.6, y=268.6
# Victim position: x=479.1, y=270.7
# Victim position: x=477.7, y=269.5
# Victim position: x=481.0, y=272.4
# Victim position: x=483.1, y=269.5
# Victim position: x=485.7, y=268.7
# Victim position: x=486.6, y=265.8
# Victim position: x=488.6, y=263.4
# Victim position: x=490.8, y=263.6
# Victim position: x=494.3, y=266.3
# Victim position: x=497.8, y=261.5
# Victim position: x=500.7, y=260.6
# Victim position: x=500.8, y=263.7
# Victim position: x=502.3, y=264.6
# Victim position: x=505.8, y=265.0
# Victim position: x=508.2, y=265.5
# Victim position: x=510.0, y=266.4
# Victim position: x=513.9, y=264.9
# Victim position: x=518.7, y=264.8
# Victim position: x=522.7, y=261.4
# Victim position: x=524.8, y=263.6
# Victim position: x=526.8, y=263.7
# Victim position: x=528.8, y=263.4
# Victim position: x=530.3, y=264.3
# Victim position: x=533.1, y=263.4
# Victim position: x=535.5, y=262.4
# Victim position: x=537.8, y=261.3
# Victim position: x=539.7, y=260.4
# Victim position: x=542.2, y=260.3
# Victim position: x=544.5, y=260.7
# Victim position: x=548.1, y=258.2
# Victim position: x=550.8, y=257.0
# Victim position: x=554.9, y=253.7
# Victim position: x=556.5, y=255.9
# Victim position: x=559.7, y=250.0
# Victim position: x=560.9, y=250.2
# Victim position: x=561.6, y=249.6
# Victim position: x=563.9, y=249.2
# Victim position: x=565.1, y=248.8
# Victim position: x=566.5, y=248.3
# Victim position: x=568.9, y=249.6
# Victim position: x=571.9, y=248.4
# Victim position: x=574.0, y=251.6
# Victim position: x=573.9, y=252.7
# Victim position: x=576.2, y=253.1
# Victim position: x=582.2, y=251.6
# Victim position: x=584.7, y=249.8
# Victim position: x=587.1, y=251.2
# Victim position: x=590.4, y=250.2
# Victim position: x=592.8, y=253.0
# Victim position: x=597.8, y=248.2
# Victim position: x=599.5, y=248.2
# Victim position: x=603.5, y=246.9
# Victim position: x=604.4, y=248.1
# Victim position: x=607.0, y=247.7
# Victim position: x=608.0, y=249.2
# Victim position: x=612.6, y=246.4
# Victim position: x=612.6, y=248.3
# Victim position: x=614.1, y=250.2
# Victim position: x=614.9, y=251.5
# Victim position: x=618.0, y=250.1
# Victim position: x=621.7, y=248.0
# Victim position: x=623.4, y=248.5
# Victim position: x=626.1, y=249.3
# Victim position: x=630.1, y=246.4
# Victim position: x=630.9, y=247.3
# Victim position: x=633.9, y=246.9
# Victim position: x=635.8, y=245.6
# Victim position: x=640.2, y=243.1
# Victim position: x=641.4, y=244.6
# Victim position: x=645.1, y=243.3
# Victim position: x=648.3, y=243.1
# Victim position: x=650.7, y=244.1
# Victim position: x=652.3, y=246.2
# Victim position: x=653.0, y=246.6
# Victim position: x=656.7, y=244.5
# Victim position: x=659.2, y=243.5
# Victim position: x=664.5, y=240.7
# Victim position: x=668.3, y=241.3
# Victim position: x=669.7, y=240.2
# Victim position: x=672.0, y=242.6
# Victim position: x=673.2, y=241.7
# Victim position: x=676.0, y=243.6
# Victim position: x=677.8, y=242.9
# Victim position: x=678.6, y=242.2
# Victim position: x=681.6, y=243.9
# Victim position: x=684.2, y=240.3
# Victim position: x=686.5, y=240.1
# Victim position: x=690.0, y=241.7
# Victim position: x=692.3, y=242.2
# Victim position: x=694.2, y=244.0
# Victim position: x=696.1, y=245.5
# Victim position: x=698.8, y=246.7
# Victim position: x=700.7, y=245.1
# Victim position: x=704.8, y=242.5
# Victim position: x=707.4, y=241.6
# Victim position: x=711.0, y=242.3
# Victim position: x=712.4, y=243.3
# Victim position: x=716.1, y=241.7
# Victim position: x=718.7, y=245.6
# Victim position: x=719.2, y=246.1
# Victim position: x=721.3, y=244.9
# Victim position: x=721.8, y=246.5
# Victim position: x=725.1, y=242.2
# Victim position: x=728.7, y=244.6
# Victim position: x=732.0, y=245.4
# Victim position: x=735.5, y=245.8
# Victim position: x=737.4, y=245.3
# Victim position: x=740.6, y=243.8
# Victim position: x=743.0, y=246.7
# Victim position: x=745.5, y=245.9
# Victim position: x=747.2, y=244.8
# Victim position: x=749.1, y=244.9
# Victim position: x=750.5, y=245.5
# Victim position: x=752.2, y=245.2
# Victim position: x=753.0, y=245.4
# Victim position: x=753.9, y=245.7
# Victim position: x=754.5, y=245.9
# Victim position: x=757.6, y=245.5
# Victim position: x=759.4, y=245.4
# Victim position: x=761.4, y=244.3
# Victim position: x=763.0, y=245.0
# Victim position: x=762.8, y=246.8
# Victim position: x=766.1, y=241.7
# Victim position: x=766.4, y=243.0
# Victim position: x=767.2, y=243.4
# Victim position: x=771.0, y=240.1
# Victim position: x=772.2, y=239.7
# Victim position: x=772.1, y=239.4
# Victim position: x=773.2, y=241.3

# %% [markdown]
# # 2- Victim Localization
#
# localization is approximated using a **planar homography** approach:
#
# 1. Four reference points on the ground are selected.
# 2. Their real-world coordinates are manually measured in **meters**.
# 3. Corresponding pixel coordinates are extracted from the image.
# 4. A homography matrix \(H\) is computed using Direct Linear Transformation (DLT).
# 5. Detected victim centroids are projected from image space to world space.
#
# This simulates the paper’s ground-plane projection step. While it does not include full robot pose estimation or SLAM, it is sufficient for demonstrating 2D tracking and sensor fusion.

# %% [markdown]
# By calculating the reference points in real world and converting those 4 points into pixels using homo_annotated.py i develop my Homography matrix

# %%
import numpy as np
import cv2

# Image points (pixels)
image_pts = np.array([
    [23, 375],    # bottom-left
    [740, 403],   # bottom-right
    [99, 93],     # top-left
    [733, 132]    # top-right
], dtype=np.float32)

# World points (meters) — rectangular ground plane
world_pts = np.array([
    [0.0, 5.5],     # bottom-left
    [11.5, 5.5],    # bottom-right
    [0.0, 0.0],     # top-left
    [11.5, 0.0]     # top-right
], dtype=np.float32)

H, _ = cv2.findHomography(image_pts, world_pts)

# %% [markdown]
# ![Figure 5: Reference World to Pixel](figs/fig_5.png)

# %%
def pixel_to_world(xy_pixel, H):
    """
    Project image pixel coordinates to world coordinates (meters)
    using homography.
    """
    pt = np.array([[xy_pixel]], dtype=np.float32)
    world = cv2.perspectiveTransform(pt, H)
    return tuple(world[0, 0])

# %%
victim_track_world = []

for r in results_aerial:
    victim_px = get_victim_xy(r)

    if victim_px is None:
        continue

    victim_w = pixel_to_world(victim_px, H)
    victim_track_world.append(victim_w)

    print(f"Victim @ X = {victim_w[0]:.2f} m, Y = {victim_w[1]:.2f} m")


victim_track_world = np.array(victim_track_world)
print("\nVictim trajectory shape:", victim_track_world.shape)
# Out:
# Victim @ X = 12.90 m, Y = 1.27 m
# Victim @ X = 12.89 m, Y = 1.30 m
# Victim @ X = 12.88 m, Y = 1.31 m
# Victim @ X = 12.87 m, Y = 1.34 m
# Victim @ X = 12.86 m, Y = 1.34 m
# Victim @ X = 12.86 m, Y = 1.35 m
# Victim @ X = 12.86 m, Y = 1.36 m
# Victim @ X = 12.85 m, Y = 1.37 m
# Victim @ X = 12.87 m, Y = 1.36 m
# Victim @ X = 12.84 m, Y = 1.40 m
# Victim @ X = 12.84 m, Y = 1.41 m
# Victim @ X = 12.83 m, Y = 1.43 m
# Victim @ X = 12.84 m, Y = 1.42 m
# Victim @ X = 12.84 m, Y = 1.42 m
# Victim @ X = 12.84 m, Y = 1.41 m
# Victim @ X = 12.86 m, Y = 1.42 m
# Victim @ X = 12.86 m, Y = 1.42 m
# Victim @ X = 12.85 m, Y = 1.44 m
# Victim @ X = 12.83 m, Y = 1.45 m
# Victim @ X = 12.86 m, Y = 1.43 m
# Victim @ X = 12.84 m, Y = 1.47 m
# Victim @ X = 12.85 m, Y = 1.48 m
# Victim @ X = 12.85 m, Y = 1.49 m
# Victim @ X = 12.86 m, Y = 1.50 m
# Victim @ X = 12.84 m, Y = 1.53 m
# Victim @ X = 12.87 m, Y = 1.49 m
# Victim @ X = 12.86 m, Y = 1.51 m
# Victim @ X = 12.85 m, Y = 1.53 m
# Victim @ X = 12.82 m, Y = 1.56 m
# Victim @ X = 12.85 m, Y = 1.52 m
# Victim @ X = 12.86 m, Y = 1.50 m
# Victim @ X = 12.86 m, Y = 1.50 m
# Victim @ X = 12.86 m, Y = 1.51 m
# Victim @ X = 12.85 m, Y = 1.52 m
# Victim @ X = 12.85 m, Y = 1.53 m
# Victim @ X = 12.84 m, Y = 1.54 m
# Victim @ X = 12.83 m, Y = 1.56 m
# Victim @ X = 12.79 m, Y = 1.59 m
# Victim @ X = 12.78 m, Y = 1.63 m
# Victim @ X = 12.78 m, Y = 1.63 m
# Victim @ X = 12.78 m, Y = 1.66 m
# Victim @ X = 12.80 m, Y = 1.61 m
# Victim @ X = 12.80 m, Y = 1.62 m
# Victim @ X = 12.81 m, Y = 1.62 m
# Victim @ X = 12.82 m, Y = 1.61 m
# Victim @ X = 12.80 m, Y = 1.59 m
# Victim @ X = 12.80 m, Y = 1.59 m
# Victim @ X = 12.81 m, Y = 1.54 m
# Victim @ X = 12.74 m, Y = 1.62 m
# Victim @ X = 12.70 m, Y = 1.63 m
# Victim @ X = 12.68 m, Y = 1.64 m
# Victim @ X = 12.63 m, Y = 1.67 m
# Victim @ X = 12.59 m, Y = 1.66 m
# Victim @ X = 12.58 m, Y = 1.62 m
# Victim @ X = 12.55 m, Y = 1.62 m
# Victim @ X = 12.51 m, Y = 1.60 m
# Victim @ X = 12.45 m, Y = 1.62 m
# Victim @ X = 12.45 m, Y = 1.59 m
# Victim @ X = 12.37 m, Y = 1.61 m
# Victim @ X = 12.35 m, Y = 1.57 m
# Victim @ X = 12.29 m, Y = 1.60 m
# Victim @ X = 12.25 m, Y = 1.62 m
# Victim @ X = 12.21 m, Y = 1.59 m
# Victim @ X = 12.15 m, Y = 1.58 m
# Victim @ X = 12.13 m, Y = 1.48 m
# Victim @ X = 12.09 m, Y = 1.44 m
# Victim @ X = 12.07 m, Y = 1.42 m
# Victim @ X = 12.02 m, Y = 1.43 m
# Victim @ X = 11.98 m, Y = 1.41 m
# Victim @ X = 11.92 m, Y = 1.40 m
# Victim @ X = 11.91 m, Y = 1.36 m
# Victim @ X = 11.84 m, Y = 1.36 m
# Victim @ X = 11.83 m, Y = 1.35 m
# Victim @ X = 11.74 m, Y = 1.43 m
# Victim @ X = 11.69 m, Y = 1.44 m
# Victim @ X = 11.63 m, Y = 1.46 m
# Victim @ X = 11.62 m, Y = 1.46 m
# Victim @ X = 11.57 m, Y = 1.44 m
# Victim @ X = 11.51 m, Y = 1.42 m
# Victim @ X = 11.42 m, Y = 1.43 m
# Victim @ X = 11.39 m, Y = 1.36 m
# Victim @ X = 11.32 m, Y = 1.41 m
# Victim @ X = 11.26 m, Y = 1.44 m
# Victim @ X = 11.23 m, Y = 1.38 m
# Victim @ X = 11.18 m, Y = 1.39 m
# Victim @ X = 11.14 m, Y = 1.39 m
# Victim @ X = 11.06 m, Y = 1.43 m
# Victim @ X = 11.03 m, Y = 1.39 m
# Victim @ X = 11.01 m, Y = 1.38 m
# Victim @ X = 10.96 m, Y = 1.38 m
# Victim @ X = 10.91 m, Y = 1.38 m
# Victim @ X = 10.85 m, Y = 1.37 m
# Victim @ X = 10.79 m, Y = 1.32 m
# Victim @ X = 10.70 m, Y = 1.36 m
# Victim @ X = 10.65 m, Y = 1.32 m
# Victim @ X = 10.57 m, Y = 1.34 m
# Victim @ X = 10.52 m, Y = 1.32 m
# Victim @ X = 10.53 m, Y = 1.23 m
# Victim @ X = 10.49 m, Y = 1.21 m
# Victim @ X = 10.44 m, Y = 1.19 m
# Victim @ X = 10.38 m, Y = 1.21 m
# Victim @ X = 10.35 m, Y = 1.16 m
# Victim @ X = 10.30 m, Y = 1.13 m
# Victim @ X = 10.22 m, Y = 1.17 m
# Victim @ X = 10.17 m, Y = 1.19 m
# Victim @ X = 10.11 m, Y = 1.23 m
# Victim @ X = 10.05 m, Y = 1.22 m
# Victim @ X = 9.99 m, Y = 1.21 m
# Victim @ X = 9.93 m, Y = 1.21 m
# Victim @ X = 9.89 m, Y = 1.18 m
# Victim @ X = 9.82 m, Y = 1.20 m
# Victim @ X = 9.76 m, Y = 1.19 m
# Victim @ X = 9.71 m, Y = 1.20 m
# Victim @ X = 9.67 m, Y = 1.17 m
# Victim @ X = 9.62 m, Y = 1.15 m
# Victim @ X = 9.56 m, Y = 1.16 m
# Victim @ X = 9.53 m, Y = 1.13 m
# Victim @ X = 9.46 m, Y = 1.14 m
# Victim @ X = 9.42 m, Y = 1.10 m
# Victim @ X = 9.37 m, Y = 1.11 m
# Victim @ X = 9.29 m, Y = 1.10 m
# Victim @ X = 9.26 m, Y = 1.15 m
# Victim @ X = 9.19 m, Y = 1.07 m
# Victim @ X = 9.12 m, Y = 1.03 m
# Victim @ X = 9.06 m, Y = 1.07 m
# Victim @ X = 8.98 m, Y = 1.09 m
# Victim @ X = 8.92 m, Y = 1.00 m
# Victim @ X = 8.88 m, Y = 0.95 m
# Victim @ X = 8.83 m, Y = 0.95 m
# Victim @ X = 8.82 m, Y = 0.91 m
# Victim @ X = 8.76 m, Y = 0.92 m
# Victim @ X = 8.72 m, Y = 0.95 m
# Victim @ X = 8.64 m, Y = 0.97 m
# Victim @ X = 8.60 m, Y = 0.93 m
# Victim @ X = 8.53 m, Y = 0.99 m
# Victim @ X = 8.50 m, Y = 1.00 m
# Victim @ X = 8.44 m, Y = 1.01 m
# Victim @ X = 8.38 m, Y = 1.00 m
# Victim @ X = 8.34 m, Y = 1.02 m
# Victim @ X = 8.28 m, Y = 1.05 m
# Victim @ X = 8.20 m, Y = 1.04 m
# Victim @ X = 8.18 m, Y = 1.00 m
# Victim @ X = 8.14 m, Y = 0.99 m
# Victim @ X = 8.09 m, Y = 0.96 m
# Victim @ X = 8.05 m, Y = 0.91 m
# Victim @ X = 8.01 m, Y = 0.93 m
# Victim @ X = 7.97 m, Y = 0.92 m
# Victim @ X = 7.92 m, Y = 0.98 m
# Victim @ X = 7.88 m, Y = 0.98 m
# Victim @ X = 7.83 m, Y = 0.95 m
# Victim @ X = 7.77 m, Y = 0.98 m
# Victim @ X = 7.70 m, Y = 0.99 m
# Victim @ X = 7.66 m, Y = 0.96 m
# Victim @ X = 7.61 m, Y = 0.93 m
# Victim @ X = 7.55 m, Y = 0.97 m
# Victim @ X = 7.48 m, Y = 0.93 m
# Victim @ X = 7.44 m, Y = 0.94 m
# Victim @ X = 7.37 m, Y = 0.94 m
# Victim @ X = 7.35 m, Y = 0.93 m
# Victim @ X = 7.21 m, Y = 0.94 m
# Victim @ X = 6.97 m, Y = 1.03 m
# Victim @ X = 6.88 m, Y = 1.10 m
# Victim @ X = 6.82 m, Y = 1.06 m
# Victim @ X = 6.77 m, Y = 1.07 m
# Victim @ X = 6.62 m, Y = 1.12 m
# Victim @ X = 6.54 m, Y = 1.06 m
# Victim @ X = 6.38 m, Y = 1.09 m
# Victim @ X = 6.32 m, Y = 1.12 m
# Victim @ X = 6.28 m, Y = 1.10 m
# Victim @ X = 6.21 m, Y = 1.13 m
# Victim @ X = 6.15 m, Y = 1.16 m
# Victim @ X = 6.10 m, Y = 1.19 m
# Victim @ X = 6.05 m, Y = 1.21 m
# Victim @ X = 5.98 m, Y = 1.17 m
# Victim @ X = 5.93 m, Y = 1.10 m
# Victim @ X = 5.88 m, Y = 1.12 m
# Victim @ X = 5.84 m, Y = 1.07 m
# Victim @ X = 5.79 m, Y = 1.06 m
# Victim @ X = 5.75 m, Y = 1.02 m
# Victim @ X = 5.66 m, Y = 1.05 m
# Victim @ X = 5.54 m, Y = 1.20 m
# Victim @ X = 5.51 m, Y = 1.16 m
# Victim @ X = 5.43 m, Y = 1.16 m
# Victim @ X = 5.38 m, Y = 1.19 m
# Victim @ X = 5.33 m, Y = 1.21 m
# Victim @ X = 5.27 m, Y = 1.17 m
# Victim @ X = 4.78 m, Y = 1.30 m
# Victim @ X = 4.21 m, Y = 1.56 m
# Victim @ X = 4.18 m, Y = 1.57 m
# Victim @ X = 4.14 m, Y = 1.60 m
# Victim @ X = 4.10 m, Y = 1.64 m
# Victim @ X = 4.08 m, Y = 1.66 m
# Victim @ X = 4.06 m, Y = 1.66 m
# Victim @ X = 4.03 m, Y = 1.68 m
# Victim @ X = 3.99 m, Y = 1.70 m
# Victim @ X = 3.96 m, Y = 1.76 m
# Victim @ X = 3.91 m, Y = 1.64 m
# Victim @ X = 3.90 m, Y = 1.71 m
# Victim @ X = 3.88 m, Y = 1.74 m
# Victim @ X = 3.86 m, Y = 1.78 m
# Victim @ X = 3.85 m, Y = 1.86 m
# Victim @ X = 3.82 m, Y = 1.87 m
# Victim @ X = 3.80 m, Y = 1.91 m
# Victim @ X = 3.77 m, Y = 1.95 m
# Victim @ X = 3.74 m, Y = 2.01 m
# Victim @ X = 3.71 m, Y = 2.04 m
# Victim @ X = 3.68 m, Y = 2.05 m
# Victim @ X = 3.67 m, Y = 2.04 m
# Victim @ X = 3.64 m, Y = 2.07 m
# Victim @ X = 3.61 m, Y = 2.08 m
# Victim @ X = 3.61 m, Y = 2.12 m
# Victim @ X = 3.59 m, Y = 2.10 m
# Victim @ X = 3.58 m, Y = 2.15 m
# Victim @ X = 3.57 m, Y = 2.19 m
# Victim @ X = 3.56 m, Y = 2.21 m
# Victim @ X = 3.56 m, Y = 2.24 m
# Victim @ X = 3.55 m, Y = 2.27 m
# Victim @ X = 3.55 m, Y = 2.32 m
# Victim @ X = 3.56 m, Y = 2.37 m
# Victim @ X = 3.56 m, Y = 2.40 m
# Victim @ X = 3.56 m, Y = 2.45 m
# Victim @ X = 3.57 m, Y = 2.48 m
# Victim @ X = 3.58 m, Y = 2.52 m
# Victim @ X = 3.59 m, Y = 2.55 m
# Victim @ X = 3.58 m, Y = 2.58 m
# Victim @ X = 3.59 m, Y = 2.61 m
# Victim @ X = 3.60 m, Y = 2.62 m
# Victim @ X = 3.59 m, Y = 2.62 m
# Victim @ X = 3.60 m, Y = 2.65 m
# Victim @ X = 3.61 m, Y = 2.69 m
# Victim @ X = 3.62 m, Y = 2.74 m
# Victim @ X = 3.62 m, Y = 2.76 m
# Victim @ X = 3.64 m, Y = 2.79 m
# Victim @ X = 3.66 m, Y = 2.85 m
# Victim @ X = 3.69 m, Y = 2.86 m
# Victim @ X = 3.71 m, Y = 2.90 m
# Victim @ X = 3.73 m, Y = 2.94 m
# Victim @ X = 3.75 m, Y = 2.97 m
# Victim @ X = 3.77 m, Y = 3.05 m
# Victim @ X = 3.81 m, Y = 3.03 m
# Victim @ X = 3.82 m, Y = 3.12 m
# Victim @ X = 3.86 m, Y = 3.20 m
# Victim @ X = 3.88 m, Y = 3.25 m
# Victim @ X = 3.88 m, Y = 3.28 m
# Victim @ X = 3.91 m, Y = 3.31 m
# Victim @ X = 3.94 m, Y = 3.24 m
# Victim @ X = 3.95 m, Y = 3.26 m
# Victim @ X = 4.02 m, Y = 3.26 m
# Victim @ X = 4.04 m, Y = 3.35 m
# Victim @ X = 4.09 m, Y = 3.31 m
# Victim @ X = 4.13 m, Y = 3.38 m
# Victim @ X = 4.14 m, Y = 3.45 m
# Victim @ X = 4.20 m, Y = 3.41 m
# Victim @ X = 4.21 m, Y = 3.33 m
# Victim @ X = 4.23 m, Y = 3.29 m
# Victim @ X = 4.36 m, Y = 3.26 m
# Victim @ X = 5.43 m, Y = 3.31 m
# Victim @ X = 5.54 m, Y = 3.26 m
# Victim @ X = 5.64 m, Y = 3.36 m
# Victim @ X = 5.69 m, Y = 3.34 m
# Victim @ X = 5.73 m, Y = 3.33 m
# Victim @ X = 5.77 m, Y = 3.34 m
# Victim @ X = 5.89 m, Y = 3.22 m
# Victim @ X = 5.88 m, Y = 3.26 m
# Victim @ X = 5.94 m, Y = 3.23 m
# Victim @ X = 5.99 m, Y = 3.25 m
# Victim @ X = 6.03 m, Y = 3.14 m
# Victim @ X = 6.08 m, Y = 3.23 m
# Victim @ X = 6.19 m, Y = 3.29 m
# Victim @ X = 6.23 m, Y = 3.29 m
# Victim @ X = 6.29 m, Y = 3.27 m
# Victim @ X = 6.29 m, Y = 3.32 m
# Victim @ X = 6.34 m, Y = 3.18 m
# Victim @ X = 6.38 m, Y = 3.19 m
# Victim @ X = 6.37 m, Y = 3.32 m
# Victim @ X = 6.37 m, Y = 3.24 m
# Victim @ X = 6.42 m, Y = 3.25 m
# Victim @ X = 6.48 m, Y = 3.11 m
# Victim @ X = 6.53 m, Y = 3.15 m
# Victim @ X = 6.56 m, Y = 3.16 m
# Victim @ X = 6.63 m, Y = 3.16 m
# Victim @ X = 6.69 m, Y = 3.12 m
# Victim @ X = 6.73 m, Y = 3.17 m
# Victim @ X = 6.80 m, Y = 3.16 m
# Victim @ X = 6.84 m, Y = 3.11 m
# Victim @ X = 6.89 m, Y = 3.14 m
# Victim @ X = 6.94 m, Y = 3.21 m
# Victim @ X = 6.96 m, Y = 3.19 m
# Victim @ X = 6.99 m, Y = 3.23 m
# Victim @ X = 6.97 m, Y = 3.21 m
# Victim @ X = 7.03 m, Y = 3.26 m
# Victim @ X = 7.06 m, Y = 3.20 m
# Victim @ X = 7.10 m, Y = 3.18 m
# Victim @ X = 7.11 m, Y = 3.13 m
# Victim @ X = 7.14 m, Y = 3.08 m
# Victim @ X = 7.18 m, Y = 3.08 m
# Victim @ X = 7.25 m, Y = 3.13 m
# Victim @ X = 7.30 m, Y = 3.03 m
# Victim @ X = 7.35 m, Y = 3.01 m
# Victim @ X = 7.35 m, Y = 3.07 m
# Victim @ X = 7.38 m, Y = 3.09 m
# Victim @ X = 7.44 m, Y = 3.09 m
# Victim @ X = 7.48 m, Y = 3.10 m
# Victim @ X = 7.52 m, Y = 3.11 m
# Victim @ X = 7.58 m, Y = 3.08 m
# Victim @ X = 7.66 m, Y = 3.07 m
# Victim @ X = 7.73 m, Y = 3.00 m
# Victim @ X = 7.77 m, Y = 3.05 m
# Victim @ X = 7.80 m, Y = 3.04 m
# Victim @ X = 7.84 m, Y = 3.04 m
# Victim @ X = 7.86 m, Y = 3.05 m
# Victim @ X = 7.91 m, Y = 3.03 m
# Victim @ X = 7.95 m, Y = 3.01 m
# Victim @ X = 7.99 m, Y = 2.99 m
# Victim @ X = 8.02 m, Y = 2.97 m
# Victim @ X = 8.06 m, Y = 2.96 m
# Victim @ X = 8.10 m, Y = 2.97 m
# Victim @ X = 8.16 m, Y = 2.91 m
# Victim @ X = 8.21 m, Y = 2.89 m
# Victim @ X = 8.28 m, Y = 2.82 m
# Victim @ X = 8.31 m, Y = 2.86 m
# Victim @ X = 8.36 m, Y = 2.74 m
# Victim @ X = 8.38 m, Y = 2.74 m
# Victim @ X = 8.39 m, Y = 2.73 m
# Victim @ X = 8.43 m, Y = 2.72 m
# Victim @ X = 8.45 m, Y = 2.71 m
# Victim @ X = 8.48 m, Y = 2.70 m
# Victim @ X = 8.52 m, Y = 2.72 m
# Victim @ X = 8.57 m, Y = 2.69 m
# Victim @ X = 8.61 m, Y = 2.76 m
# Victim @ X = 8.61 m, Y = 2.78 m
# Victim @ X = 8.65 m, Y = 2.78 m
# Victim @ X = 8.76 m, Y = 2.75 m
# Victim @ X = 8.80 m, Y = 2.71 m
# Victim @ X = 8.84 m, Y = 2.73 m
# Victim @ X = 8.90 m, Y = 2.71 m
# Victim @ X = 8.94 m, Y = 2.77 m
# Victim @ X = 9.03 m, Y = 2.66 m
# Victim @ X = 9.06 m, Y = 2.66 m
# Victim @ X = 9.13 m, Y = 2.63 m
# Victim @ X = 9.14 m, Y = 2.65 m
# Victim @ X = 9.19 m, Y = 2.64 m
# Victim @ X = 9.21 m, Y = 2.67 m
# Victim @ X = 9.29 m, Y = 2.61 m
# Victim @ X = 9.29 m, Y = 2.65 m
# Victim @ X = 9.32 m, Y = 2.69 m
# Victim @ X = 9.33 m, Y = 2.71 m
# Victim @ X = 9.38 m, Y = 2.68 m
# Victim @ X = 9.45 m, Y = 2.63 m
# Victim @ X = 9.48 m, Y = 2.64 m
# Victim @ X = 9.53 m, Y = 2.66 m
# Victim @ X = 9.60 m, Y = 2.59 m
# Victim @ X = 9.61 m, Y = 2.61 m
# Victim @ X = 9.66 m, Y = 2.60 m
# Victim @ X = 9.70 m, Y = 2.57 m
# Victim @ X = 9.78 m, Y = 2.51 m
# Victim @ X = 9.80 m, Y = 2.54 m
# Victim @ X = 9.86 m, Y = 2.51 m
# Victim @ X = 9.92 m, Y = 2.51 m
# Victim @ X = 9.96 m, Y = 2.52 m
# Victim @ X = 9.99 m, Y = 2.57 m
# Victim @ X = 10.01 m, Y = 2.57 m
# Victim @ X = 10.07 m, Y = 2.53 m
# Victim @ X = 10.12 m, Y = 2.50 m
# Victim @ X = 10.21 m, Y = 2.44 m
# Victim @ X = 10.28 m, Y = 2.45 m
# Victim @ X = 10.30 m, Y = 2.42 m
# Victim @ X = 10.35 m, Y = 2.47 m
# Victim @ X = 10.37 m, Y = 2.45 m
# Victim @ X = 10.42 m, Y = 2.49 m
# Victim @ X = 10.45 m, Y = 2.47 m
# Victim @ X = 10.46 m, Y = 2.46 m
# Victim @ X = 10.52 m, Y = 2.49 m
# Victim @ X = 10.57 m, Y = 2.41 m
# Victim @ X = 10.61 m, Y = 2.40 m
# Victim @ X = 10.67 m, Y = 2.43 m
# Victim @ X = 10.71 m, Y = 2.44 m
# Victim @ X = 10.74 m, Y = 2.48 m
# Victim @ X = 10.78 m, Y = 2.50 m
# Victim @ X = 10.83 m, Y = 2.53 m
# Victim @ X = 10.86 m, Y = 2.49 m
# Victim @ X = 10.94 m, Y = 2.43 m
# Victim @ X = 10.98 m, Y = 2.41 m
# Victim @ X = 11.05 m, Y = 2.42 m
# Victim @ X = 11.07 m, Y = 2.44 m
# Victim @ X = 11.14 m, Y = 2.40 m
# Victim @ X = 11.19 m, Y = 2.48 m
# Victim @ X = 11.20 m, Y = 2.49 m
# Victim @ X = 11.23 m, Y = 2.47 m
# Victim @ X = 11.24 m, Y = 2.50 m
# Victim @ X = 11.30 m, Y = 2.40 m
# Victim @ X = 11.37 m, Y = 2.45 m
# Victim @ X = 11.43 m, Y = 2.46 m
# Victim @ X = 11.49 m, Y = 2.47 m
# Victim @ X = 11.53 m, Y = 2.46 m
# Victim @ X = 11.59 m, Y = 2.42 m
# Victim @ X = 11.63 m, Y = 2.48 m
# Victim @ X = 11.67 m, Y = 2.46 m
# Victim @ X = 11.71 m, Y = 2.43 m
# Victim @ X = 11.74 m, Y = 2.43 m
# Victim @ X = 11.77 m, Y = 2.45 m
# Victim @ X = 11.80 m, Y = 2.44 m
# Victim @ X = 11.81 m, Y = 2.44 m
# Victim @ X = 11.83 m, Y = 2.45 m
# Victim @ X = 11.84 m, Y = 2.45 m
# Victim @ X = 11.89 m, Y = 2.44 m
# Victim @ X = 11.93 m, Y = 2.43 m
# Victim @ X = 11.97 m, Y = 2.41 m
# Victim @ X = 11.99 m, Y = 2.42 m
# Victim @ X = 11.99 m, Y = 2.46 m
# Victim @ X = 12.05 m, Y = 2.35 m
# Victim @ X = 12.06 m, Y = 2.38 m
# Victim @ X = 12.07 m, Y = 2.38 m
# Victim @ X = 12.14 m, Y = 2.31 m
# Victim @ X = 12.17 m, Y = 2.30 m
# Victim @ X = 12.16 m, Y = 2.30 m
# Victim @ X = 12.18 m, Y = 2.33 m
#
# Victim trajectory shape: (417, 2)

# %%
cap = cv2.VideoCapture("Data/vid1_A_aerial.mp4")

frame_idx = 200
cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)  # <<< THIS WAS MISSING

ret, frame = cap.read()
cap.release()

if not ret:
    raise RuntimeError(f"Could not read frame {frame_idx}")

r = results_aerial[frame_idx]
victim_px = get_victim_xy(r)

if victim_px is None:
    raise RuntimeError("No victim detected in selected frame")

# Pixel → World
pt = np.array([[victim_px]], dtype=np.float32)
victim_world = cv2.perspectiveTransform(pt, H)[0, 0]

Xw, Yw = victim_world
x_px, y_px = int(victim_px[0]), int(victim_px[1])

origin_px = (99, 93)

cv2.circle(frame, origin_px, 8, (255, 0, 0), -1)
cv2.putText(frame, "World (0,0)",
            (origin_px[0] + 5, origin_px[1] - 5),
            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

cv2.circle(frame, (x_px, y_px), 8, (0, 0, 255), -1)
cv2.putText(frame, f"Victim ({Xw:.2f} m, {Yw:.2f} m)",
            (x_px + 5, y_px - 5),
            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

cv2.imwrite("victim_localization_frame200.png", frame)
cv2.imshow("Victim Localization (World Coordinates)", frame)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %% [markdown]
# ![Figure 6: Localized 2D](figs/fig_6.png)

# %% [markdown]
# # 3- Victim Tracking
#
# ## Kalman Filter (KF)
#
# ### State Definition and Motion Model
#
# We adopt a **2D constant-velocity motion model**, consistent with the formulation used in the paper:
#
# \begin{equation}
# \mathbf{x}_k =
# \begin{bmatrix}
# p_x(k) \\
# p_y(k) \\
# v_x(k) \\
# v_y(k)
# \end{bmatrix}
# \end{equation}
#
# where \(p_x, p_y\) denote the target position in pixel coordinates and
# \(v_x, v_y\) denote the corresponding velocity components.
#
# The discrete-time state transition model is given by:
#
# \begin{equation}
# \mathbf{x}_{k|k-1} = \mathbf{A}\mathbf{x}_{k-1|k-1} + \mathbf{w}_k
# \end{equation}
#
# with
#
# \begin{equation}
# \mathbf{A} =
# \begin{bmatrix}
# 1 & 0 & \Delta t & 0 \\
# 0 & 1 & 0 & \Delta t \\
# 0 & 0 & 1 & 0 \\
# 0 & 0 & 0 & 1
# \end{bmatrix}
# \end{equation}
#
# and process noise
#
# \begin{equation}
# \mathbf{w}_k \sim \mathcal{N}(0, \mathbf{Q})
# \end{equation}
#
# This model assumes linear motion with approximately constant velocity between consecutive video frames, which is a reasonable assumption for human walking motion at typical frame rates.
#
# ---
#
# ### Measurement Model
#
# Only 2D position measurements are available from pose detection. The measurement model is therefore:
#
# \begin{equation}
# \mathbf{z}_k = \mathbf{H}\mathbf{x}_k + \mathbf{v}_k
# \end{equation}
#
# where
#
# \begin{equation}
# \mathbf{H} =
# \begin{bmatrix}
# 1 & 0 & 0 & 0 \\
# 0 & 1 & 0 & 0
# \end{bmatrix}
# \end{equation}
#
# and the measurement noise is modeled as:
#
# \begin{equation}
# \mathbf{v}_k \sim \mathcal{N}(0, \mathbf{R})
# \end{equation}
#
# No direct velocity measurements are available. Velocity is treated as a **hidden state** and is implicitly estimated by the Kalman Filter through successive position updates.
#
# ---
#
# ### Kalman Filter Equations
#
# **Prediction step:**
#
# \begin{equation}
# \hat{\mathbf{x}}_{k|k-1} = \mathbf{A}\hat{\mathbf{x}}_{k-1|k-1}
# \end{equation}
#
# \begin{equation}
# \mathbf{P}_{k|k-1} = \mathbf{A}\mathbf{P}_{k-1|k-1}\mathbf{A}^\top + \mathbf{Q}
# \end{equation}
#
# **Innovation (measurement residual):**
#
# \begin{equation}
# \mathbf{y}_k = \mathbf{z}_k - \mathbf{H}\hat{\mathbf{x}}_{k|k-1}
# \end{equation}
#
# \begin{equation}
# \mathbf{S}_k = \mathbf{H}\mathbf{P}_{k|k-1}\mathbf{H}^\top + \mathbf{R}
# \end{equation}
#
# **Kalman gain:**
#
# \begin{equation}
# \mathbf{K}_k = \mathbf{P}_{k|k-1}\mathbf{H}^\top \mathbf{S}_k^{-1}
# \end{equation}
#
# **Update step:**
#
# \begin{equation}
# \hat{\mathbf{x}}_{k|k} = \hat{\mathbf{x}}_{k|k-1} + \mathbf{K}_k \mathbf{y}_k
# \end{equation}
#
# \begin{equation}
# \mathbf{P}_{k|k} = (\mathbf{I} - \mathbf{K}_k \mathbf{H})\mathbf{P}_{k|k-1}
# \end{equation}
#
# ---
#
# ### Noise Modeling and Tuning
#
# - **Process noise covariance Q** accounts for unmodeled acceleration and motion uncertainty.
# - **Measurement noise covariance R** captures pose-detection noise in pixel space.
#
# The tuning follows the same principle described in the paper:
# the filter relies more on the motion model when measurements are unreliable and more on measurements when detections are consistent.
#
# ## 1- Setup

# %%
class PixelKalmanFilter:
    def __init__(self, dt=1/30):
        # State vector: x_k = [px, py, vx, vy]^T
        self.x = np.zeros((4,1))              # \hat{x}_{k|k}
        self.P = np.eye(4) * 100.0            # P_{k|k}

        self.dt = dt

        # State transition matrix A
        self.A = np.array([
            [1, 0, dt, 0],
            [0, 1, 0, dt],
            [0, 0, 1,  0],
            [0, 0, 0,  1]
        ])

        # Measurement matrix H
        self.H = np.array([
            [1, 0, 0, 0],
            [0, 1, 0, 0]
        ])

        # TUNED FROM 0.01, 25
        # Process noise covariance Q
        self.Q = np.eye(4) * 3

        # Measurement noise covariance R
        self.R = np.eye(2) * 20

        self.I = np.eye(4)

    def predict(self):
        # Prediction:
        # x_{k|k-1} = A x_{k-1|k-1}
        # P_{k|k-1} = A P_{k-1|k-1} A^T + Q
        self.x = self.A @ self.x
        self.P = self.A @ self.P @ self.A.T + self.Q
        return self.x

    def update(self, z):
        if z is None:
            return

        z = np.array(z).reshape((2,1))  # z_k

        # Innovation (residual)
        y = z - self.H @ self.x         # y_k

        # Innovation covariance
        S = self.H @ self.P @ self.H.T + self.R  # S_k

        # Kalman gain
        K = self.P @ self.H.T @ np.linalg.inv(S) # K_k

        # State update
        self.x = self.x + K @ y         # x_{k|k}

        # Covariance update
        self.P = (self.I - K @ self.H) @ self.P  # P_{k|k}

    def state(self):
        return self.x.flatten()

# %% [markdown]
# ## 2- Filtering
#
# Here we will track the predictions(P), update(U) and measurements(z).
# We will also vary states by varying number of frames that the filter takes in

# %%
cap = cv2.VideoCapture("Data/vid1_A_aerial.mp4")
kf = PixelKalmanFilter(dt=1/30)

frame_idx = 0
frame_stride = 5  # visualize every 20th frame

pred_history = []
meas_history = []
upd_history  = []

# --- Warm-up settings ---
kf_steps = 0
WARMUP_STEPS = 3   # ignore first 5 KF updates


while True:
    ret, frame = cap.read()
    if not ret or frame_idx >= len(results_aerial):
        break

    # --- VISUALIZE EVERY 20th FRAME ---
    if frame_idx % frame_stride == 0:
        r = results_aerial[frame_idx]

        # --- KF PREDICTION ---
        x_pred = kf.predict()
        pred_pt = (int(x_pred[0]), int(x_pred[1]))

        # --- MEASUREMENT ---
        victim_xy = get_victim_xy(r)

        # --- KF UPDATE ---
        kf.update(victim_xy)
        kf_steps += 1

        x_est, y_est, vx_est, vy_est = kf.state()
        upd_pt = (int(x_est), int(y_est))

        # ------------------ STORE TRACKING PATH (after warm-up) ------------------
        if kf_steps > WARMUP_STEPS:
            pred_history.append(pred_pt)
            upd_history.append(upd_pt)

            if victim_xy is not None:
                meas_pt = (int(victim_xy[0]), int(victim_xy[1]))
                meas_history.append(meas_pt)

        # ------------------ DRAW MEASUREMENT ------------------
        if victim_xy is not None:
            meas_pt = (int(victim_xy[0]), int(victim_xy[1]))
            cv2.circle(frame, meas_pt, 6, (0, 0, 255), -1)
            cv2.putText(frame, "Measurement", (meas_pt[0]+5, meas_pt[1]),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 1)

        # ------------------ DRAW POINTS ------------------
        cv2.circle(frame, pred_pt, 6, (255, 0, 0), -1)
        cv2.putText(frame, "Prediction", (pred_pt[0]+5, pred_pt[1]),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 1)

        cv2.circle(frame, upd_pt, 6, (0, 255, 0), -1)
        cv2.putText(frame, "Update", (upd_pt[0]+5, upd_pt[1]),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 1)

        # ------------------ DRAW TRACKING PATHS ------------------
        for i in range(1, len(pred_history)):
            cv2.line(frame, pred_history[i-1], pred_history[i], (255, 0, 0), 2)

        for i in range(1, len(upd_history)):
            cv2.line(frame, upd_history[i-1], upd_history[i], (0, 255, 0), 2)

        for i in range(1, len(meas_history)):
            cv2.line(frame, meas_history[i-1], meas_history[i], (0, 0, 255), 2)

        cv2.imshow("KF Victim Tracking (Aerial)", frame)

        if cv2.waitKey(200) & 0xFF == ord('q'):
            break

    frame_idx += 1

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9240\3963850996.py:27: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   pred_pt = (int(x_pred[0]), int(x_pred[1]))

# %% [markdown]
# For every 5 frames:
#
# ![Figure 7: KF visualized](figs/fig_7.png)
#
# for every 20 frames:
#
# ![Figure 8: KF visualizedd](figs/fig_8.png)

# %% [markdown]
# ## Conclusion
#
# This notebook demonstrates a simplified yet faithful replication of the paper’s detection, localization, and tracking pipeline. While several components are approximated (centroid-based victim localization, planar homography, 2D motion model), the core ideas—robust human detection, projection into world coordinates, and Kalman-filter-based trajectory estimation—are preserved and validated through implementation.
#
# For elevation estmation, following data has been recorded that can be used for distance edtimation and Z location of the victim.

# %% [markdown]
# # 4-Future recommendations
# ------------------------------
# CAMERA & SCENE SPECIFICATIONS
# ------------------------------
#
# Victim real height (S_real):
# - 63 inches
# - 1.60 meters
#
# Victim image height (S_img):
# - 66 pixels
#
# ------------------------------
# AERIAL CAMERA (Samsung A25)
# ------------------------------
# Camera height (Z):
# - 9.5 meters
#
# Camera tilt:
# - 45 degrees downward
#
# Camera horizontal FOV:
# - 76 degrees
#
# Camera vertical FOV:
# - 56 degrees
#
# Fig 7 from paper:
#
# ![Figure 9: FOVs](figs/fig_9.png)
#
# Camera position relative to world origin (0,0):
# - X_cam = 4.5 meters
# - Y_cam = 8.8 meters
#
# Ground reference dimensions:
# - Width (X): 11.5 meters
# - Height (Y): 5.5 meters
#
# Homography reference:
# World (meters):
# (0.0, 0.0)     -> top-left
# (11.5, 0.0)    -> top-right
# (0.0, 5.5)     -> bottom-left
# (11.5, 5.5)    -> bottom-right
#
# Image (pixels):
# top-left     = (99, 93)
# top-right    = (733, 132)
# bottom-left  = (23, 375)
# bottom-right = (740, 403)
#
# ------------------------------
# GROUND CAMERA (iPhone 11)
# ------------------------------
# Camera height (Z):
# - 2.75 meters
#
# Camera horizontal FOV:
# - 77 degrees
#
# Camera vertical FOV:
# - 59 degrees
#
# Camera position relative to world origin (0,0):
# - X_cam = 13.0 meters
# - Y_cam = 0.0 meters
#
# Reference pixel corresponding to world (0,0):
# - (93, 99)
#
# ![Figure 10: Drawing](figs/fig_10.jpg)
# ------------------------------
# IMAGE PARAMETERS
# ------------------------------
# Image width (W_img):
# - from code
#
# Image height (H_img):
# - from code
